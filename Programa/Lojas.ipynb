# %% [markdown]
# # Armas Corporais

# %%
#Classe que define as armas corporais do jogo.
class Arma_Corporal():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.dano = i.offset(row = 0,column = 2).value
        self.tipo = i.offset(row = 0,column = 3).value.split(',')
        self.FN = float(i.offset(row = 0,column = 4).value)
        self.peso = i.offset(row = 0,column = 5).value
        self.distancia = i.offset(row = 0,column = 6).value
        if i.offset(row = 0,column = 7).value != None: self.obs = i.offset(row = 0,column = 7).value.split(',')
        else: self.obs = []
    def __repr__(self): return self.nome

armas_corporais = []
#Cria todas as armas corporais como objetos da classe Armas_Corporal.
for col in dados['Armas_Corporal'].iter_cols(min_col = 1, min_row = 2, max_row = 28, max_col = 1):
    for cell in col: globals()[cell.value] = Arma_Corporal(cell) ; armas_corporais.append(globals()[cell.value])
        
#Armas
def loja_armas_corporais(per):
    print('\n') ; nomes_itens = []
    for item in armas_corporais: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Armas Corporais.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual arma corporal que deseja comprar? ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é uma arma corporal.')
            elif globals()[item].nome == 'soco_chute': print('Você não precisa comprar mãos e pernas... mas aceitamos pagamento! :)')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

# %% [markdown]
# # Armadura

# %%
#Classe que define as armaduras do jogo.
class Armadura():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.defesa = i.offset(row = 0,column = 2).value
        self.FN = float(i.offset(row = 0,column = 3).value)
        self.peso = i.offset(row = 0,column = 4).value
        if i.offset(row = 0,column = 5).value != None: self.obs = i.offset(row = 0,column = 5).value.split(',')
        else: self.obs = []
    def __repr__(self): return self.nome

armaduras = []
for col in dados['Armaduras'].iter_cols(min_col = 1, min_row = 2, max_row = 9, max_col = 1):
    for cell in col: globals()[cell.value] = Armadura(cell) ; armaduras.append(globals()[cell.value])
        
def loja_armaduras(per):
    print('\n') ; nomes_itens = []
    for item in armaduras: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Armaduras.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual armadura que deseja comprar: ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é uma armadura.')
            else: break
        while True:
            try:
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada:
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

# %% [markdown]
# # Armas Distância

# %%
#Classe que define as armas de distâncias e as munições do jogo
class Arma_Distancia():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.dano = i.offset(row = 0,column = 2).value
        self.tipo = i.offset(row = 0,column = 3).value.split(',')
        self.FN = float(i.offset(row = 0,column = 4).value)
        self.peso = i.offset(row = 0,column = 5).value
        self.distancia = i.offset(row = 0,column = 6).value
        self.municao = i.offset(row = 0,column = 7).value.split(',')
        if i.offset(row = 0,column = 8).value != None: self.obs = i.offset(row = 0,column = 8).value.split(',')
        else: self.obs = []
    def __repr__(self): return self.nome

class Municao():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.peso = i.offset(row = 0,column = 2).value
        self.obs = i.offset(row = 0,column = 3).value.split(',')
    def __repr__(self): return self.nome

armas_distancia = []
municao = []
for col in dados['Armas_Distancia'].iter_cols(min_col = 1, min_row = 2, max_row = 12, max_col = 1):
    for cell in col: globals()[cell.value] = Arma_Distancia(cell) ; armas_distancia.append(globals()[cell.value])
for col in dados['Armas_Distancia'].iter_cols(min_col = 10, min_row = 2, max_row = 7, max_col = 10):
    for cell in col: globals()[cell.value] = Municao(cell) ; municao.append(globals()[cell.value])
        
#Loja Armas de Distância
def loja_armas_distancia(per):
    print('\n') ; nomes_itens = []
    for item in armas_distancia: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Armas de Distância.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual arma de distância que deseja comprar? ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é uma arma de distância.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

#Loja Munição
def loja_municao(per): #recalcular peso do personagem de acordo com munição.
    print('\n') ; nomes_itens = []
    for item in municao: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,', Armas =',item.obs,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Munições.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual munição deseja comprar? ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é uma munição.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos# Instrumentos Musicais

# %% [markdown]
# # Instrumentos Musicais

# %%
class Instrumento_Musical():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.FN = float(i.offset(row = 0,column = 2).value)
        self.peso = i.offset(row = 0,column = 3).value
        if i.offset(row = 0,column = 4).value != None: self.obs = i.offset(row = 0,column = 4).value.split(',')
        else: self.obs = []
    def __repr__(self): return self.nome
    
instrumentos_musicais = []
for col in dados['Instrumentos_Musicais'].iter_cols(min_col = 1, min_row = 2, max_row = 16, max_col = 1):
    for cell in col: globals()[cell.value] = Instrumento_Musical(cell) ; instrumentos_musicais.append(globals()[cell.value])
        
def loja_instrumentos_musicais(per):
    print('\n') ; nomes_itens = []
    for item in instrumentos_musicais: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Instrumentos Musicais.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual instrumento musical que deseja comprar: ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é um instrumento musical.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

# %% [markdown]
# # Itens de Conjuração

# %%
#Classe que define os ítens de conjuração do jogo.
class Item_Conjuracao():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.dano = i.offset(row = 0,column = 1).value
        self.tipo = i.offset(row = 0,column = 2).value.split(',')
        self.distancia = i.offset(row = 0,column = 3).value
        self.custo = i.offset(row = 0,column = 4).value
        self.FN = float(i.offset(row = 0,column = 5).value)
        self.peso = i.offset(row = 0,column = 6).value
        self.obs = i.offset(row = 0,column = 8).value.split(',')
    def __repr__(self): return self.nome

itens_conjuracao = []
#Cria todas os ítens de conjuração como objetos da classe Item_Conjuracao.
for col in dados['Itens_Conjuracao'].iter_cols(min_col = 1, min_row = 2, max_row = 9, max_col = 1):
    for cell in col: globals()[cell.value] = Item_Conjuracao(cell) ; itens_conjuracao.append(globals()[cell.value])
        
#Ítens de Conjuração
def loja_itens_conjuracao(per):
    print('\n') ; nomes_itens = []
    for item in itens_conjuracao:
        print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de ítens de Conjuração') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual ítem de conjuração que deseja comprar: ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é um ítem de conjuracao.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else: 
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's': 
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

# %% [markdown]
# # Itens Gerais

# %%
class Item_Geral():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.peso = i.offset(row = 0,column = 2).value
        self.obs = ["item_geral"]
    def __repr__(self): return self.nome
    
itens_gerais = []
for col in dados['Itens_Gerais'].iter_cols(min_col = 1, min_row = 2, max_row = 61, max_col = 1):
    for cell in col: globals()[cell.value] = Item_Geral(cell) ; itens_gerais.append(globals()[cell.value])
        
def loja_itens_gerais(per):
    print('\n') ; nomes_itens = []
    for item in itens_gerais: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Ítens Gerais.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual produto comprar? ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é um ítem.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

# %% [markdown]
# # Poções

# %%
class Pocao():
    #Atributos dos ítens.
    def __init__(self,i):
        self.nome = i.offset(row = 0,column = 0).value
        self.custo = i.offset(row = 0,column = 1).value
        self.peso = i.offset(row = 0,column = 2).value
        self.aura = i.offset(row = 0,column = 3).value
        self.efeito = i.offset(row = 0,column = 4).value
        self.obs=["uso_unico"]
    def __repr__(self): return self.nome
    
pocoes = []
for col in dados['Pocoes'].iter_cols(min_col = 1, min_row = 2, max_row = 6, max_col = 1):
    for cell in col: globals()[cell.value] = Pocao(cell) ; pocoes.append(globals()[cell.value])
        
def loja_pocoes(per):
    print('\n') ; nomes_itens = []
    for item in pocoes: print(item,'-------------------- Peso=',item.peso,', Custo=',item.custo,'\n') ; nomes_itens.append(item.nome)
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Loja de Poções.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual poção deseja comprar? ')
            if item == 'sair': per.recalcular_atributos ; print('\n') ; return
            if item not in nomes_itens: print('Isso não é uma poção.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': per.recalcular_atributos ; print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = globals()[item].custo*quantidade ; peso_total = globals()[item].peso*quantidade
        if per.peso + peso_total > per.carga_pesada: 
            print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Excederá a sua carga pesada.')
        elif per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            if per.peso + peso_total > per.carga_basica:
                print('O peso dos itens do jogador será igual a ' + str(per.peso + peso_total) + '. Ficará pesado.')
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': per.recalcular_atributos ; print('\n') ; return
            if confirma == 's':
                if globals()[item] not in per.itens: per.itens.append(globals()[item]) ; per.qtd_itens[item] = quantidade
                else: per.qtd_itens[item] += quantidade
                per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.') ; per.recalcular_atributos

# %% [markdown]
# # Serviços

# %%
#Tavernas, Hospedarias e Caravanas
def serviços(per):
    print('\n')
    for item in servicos: print(item,'-------------------- Custo=',servicos[item],'\n')
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à Taverna.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('O que deseja? ')
            if item == 'sair': print('\n') ; return
            if item not in servicos: print('Não temos esse serviço aqui.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = servicos[item]*quantidade
        if per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': print('\n') ; return
            if confirma == 's': per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.')

# %% [markdown]
# # Transportes

# %%
#Transporte
transportes = {}
for col in dados['Transportes'].iter_cols(min_col = 1, min_row = 2, max_row = 10, max_col = 1):
    for cell in col: transportes[cell.value] = cell.offset(row = 0,column = 1).value
def transporte(per):
    print('\n')
    for item in transportes: print(item,'-------------------- Custo=',transportes[item],'\n')
    print('Olá ' + per.nome + '.') ; print('Bem-vindo à área de transportes.') ; print('Para finalizar a compra, digite: sair')
    print('Você tem ' + str(per.gold) + ' de gold.') ; print('\n')
    while True:
        while True:
            item = input('Qual meio de transporte deseja utilizar? ')
            if item == 'sair': print('\n') ; return
            if item not in transportes: print('Não temos esse meio de transporte aqui.')
            else: break
        while True:
            try: 
                quantidade = input('Qual quantidade? ')
                if quantidade == 'sair': print('\n') ; return
                quantidade = int(quantidade)
            except ValueError: print('Digite um número inteiro.') ; continue
            else: break
        custo_total = transportes[item]*quantidade
        if per.gold < custo_total: print('Vai custar ' + str(custo_total) + ' gold. ' + 'Você tem ' + str(per.gold) + ' de gold. Não tem gold o suficiente.')
        else:
            confirma = input('Vai custar ' + str(custo_total) + '. Você tem ' + str(per.gold) + ' gold. Confirma?(s/n) ')
            while confirma != 's' and confirma != 'n' and confirma != 'sair':
                confirma = input('Vai custar' + str(custo_total) + '. Você tem ' + str(per.gold) + ' de gold. Confirma?(s/n) ')
            if confirma == 'sair': print('\n') ; return
            if confirma == 's': per.gold -= custo_total ; print('Você tem ' + str(per.gold) + ' de gold.')
